# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

# %%
import pymongo

# %%
from pymongo import MongoClient
import dns.resolver

dns.resolver.default_resolver=dns.resolver.Resolver(configure=False)
dns.resolver.default_resolver.nameservers=['8.8.8.8']

# %%
f
# Out:
# ❌ Connection failed: SSL handshake failed: cluster0-shard-00-00.krsd2.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:997) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),SSL handshake failed: cluster0-shard-00-02.krsd2.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:997) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),SSL handshake failed: cluster0-shard-00-01.krsd2.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:997) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 67f111c9d0c1e2d3ab63b41a, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('cluster0-shard-00-00.krsd2.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('SSL handshake failed: cluster0-shard-00-00.krsd2.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:997) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>, <ServerDescription ('cluster0-shard-00-01.krsd2.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('SSL handshake failed: cluster0-shard-00-01.krsd2.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:997) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>, <ServerDescription ('cluster0-shard-00-02.krsd2.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('SSL handshake failed: cluster0-shard-00-02.krsd2.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:997) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>

# %%
import certifi
from pymongo import MongoClient
import ssl
# Out:
# ✅ Connected to MongoDB v8.0.6

# %%
DB_NAME = "Credit_records"
COLLECTION_NAME = "credit _data"
uri = "0"

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))
# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
from pymongo import MongoClient

# %%
 # List all database names
db_names = client.list_database_names()
print("Databases available:", db_names)
# Out:
# Databases available: ['admin', 'local']

# %%
db = client["admin"]
collections = db.list_collection_names()
print(f"Collections in {db.name}:", collections)
# Out:
# Collections in admin: []

# %%
import pandas as pd
data=pd.read_csv("credit_risk_dataset.csv")

# %%
data.head()
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0          22          59000                  RENT              123.0
# 1          21           9600                   OWN                5.0
# 2          25           9600              MORTGAGE                1.0
# 3          23          65500                  RENT                4.0
# 4          24          54400                  RENT                8.0
#
#   loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0    PERSONAL          D      35000          16.02            1
# 1   EDUCATION          B       1000          11.14            0
# 2     MEDICAL          C       5500          12.87            1
# 3     MEDICAL          C      35000          15.23            1
# 4     MEDICAL          C      35000          14.27            1
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# 0                 0.59                         Y                           3
# 1                 0.10                         N                           2
# 2                 0.57                         N                           3
# 3                 0.53                         N                           2
# 4                 0.55                         Y                           4

# %%
data.columns
# Out:
# Index(['person_age', 'person_income', 'person_home_ownership',
#        'person_emp_length', 'loan_intent', 'loan_grade', 'loan_amnt',
#        'loan_int_rate', 'loan_status', 'loan_percent_income',
#        'cb_person_default_on_file', 'cb_person_cred_hist_length'],
#       dtype='object')

# %%
data.shape
# Out:
# (32581, 12)

# %%
data=data.to_dict(orient='records')

# %%
data
# Out:
# [{'person_age': 22,
#   'person_income': 59000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 123.0,
#   'loan_intent': 'PERSONAL',
#   'loan_grade': 'D',
#   'loan_amnt': 35000,
#   'loan_int_rate': 16.02,
#   'loan_status': 1,
#   'loan_percent_income': 0.59,
#   'cb_person_default_on_file': 'Y',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 21,
#   'person_income': 9600,
#   'person_home_ownership': 'OWN',
#   'person_emp_length': 5.0,
#   'loan_intent': 'EDUCATION',
#   'loan_grade': 'B',
#   'loan_amnt': 1000,
#   'loan_int_rate': 11.14,
#   'loan_status': 0,
#   'loan_percent_income': 0.1,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 25,
#   'person_income': 9600,
#   'person_home_ownership': 'MORTGAGE',
#   'person_emp_length': 1.0,
#   'loan_intent': 'MEDICAL',
#   'loan_grade': 'C',
#   'loan_amnt': 5500,
#   'loan_int_rate': 12.87,
#   'loan_status': 1,
#   'loan_percent_income': 0.57,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 23,
#   'person_income': 65500,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 4.0,
#   'loan_intent': 'MEDICAL',
#   'loan_grade': 'C',
#   'loan_amnt': 35000,
#   'loan_int_rate': 15.23,
#   'loan_status': 1,
#   'loan_percent_income': 0.53,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 24,
#   'person_income': 54400,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 8.0,
#   'loan_intent': 'MEDICAL',
#   'loan_grade': 'C',
#   'loan_amnt': 35000,
#   'loan_int_rate': 14.27,
#   'loan_status': 1,
#   'loan_percent_income': 0.55,
#   'cb_person_default_on_file': 'Y',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 21,
#   'person_income': 9900,
#   'person_home_ownership': 'OWN',
#   'person_emp_length': 2.0,
#   'loan_intent': 'VENTURE',
#   'loan_grade': 'A',
#   'loan_amnt': 2500,
#   'loan_int_rate': 7.14,
#   'loan_status': 1,
#   'loan_percent_income': 0.25,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 26,
#   'person_income': 77100,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 8.0,
#   'loan_intent': 'EDUCATION',
#   'loan_grade': 'B',
#   'loan_amnt': 35000,
#   'loan_int_rate': 12.42,
#   'loan_status': 1,
#   'loan_percent_income': 0.45,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 24,
#   'person_income': 78956,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 5.0,
#   'loan_intent': 'MEDICAL',
#   'loan_grade': 'B',
#   'loan_amnt': 35000,
#   'loan_int_rate': 11.11,
#   'loan_status': 1,
#   'loan_percent_income': 0.44,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 24,
#   'person_income': 83000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 8.0,
#   'loan_intent': 'PERSONAL',
#   'loan_grade': 'A',
#   'loan_amnt': 35000,
#   'loan_int_rate': 8.9,
#   'loan_status': 1,
#   'loan_percent_income': 0.42,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 21,
#   'person_income': 10000,
#   'person_home_ownership': 'OWN',
#   'person_emp_length': 6.0,
#   'loan_intent': 'VENTURE',
#   'loan_grade': 'D',
#   'loan_amnt': 1600,
#   'loan_int_rate': 14.74,
#   'loan_status': 1,
#   'loan_percent_income': 0.16,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 22,
#   'person_income': 85000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 6.0,
#   'loan_intent': 'VENTURE',
#   'loan_grade': 'B',
#   'loan_amnt': 35000,
#   'loan_int_rate': 10.37,
#   'loan_status': 1,
#   'loan_percent_income': 0.41,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 21,
#   'person_income': 10000,
#   'person_home_ownership': 'OWN',
#   'person_emp_length': 2.0,
#   'loan_intent': 'HOMEIMPROVEMENT',
#   'loan_grade': 'A',
#   'loan_amnt': 4500,
#   'loan_int_rate': 8.63,
#   'loan_status': 1,
#   'loan_percent_income': 0.45,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 23,
#   'person_income': 95000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 2.0,
#   'loan_intent': 'VENTURE',
#   'loan_grade': 'A',
#   'loan_amnt': 35000,
#   'loan_int_rate': 7.9,
#   'loan_status': 1,
#   'loan_percent_income': 0.37,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 26,
#   'person_income': 108160,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 4.0,
#   'loan_intent': 'EDUCATION',
#   'loan_grade': 'E',
#   'loan_amnt': 35000,
#   'loan_int_rate': 18.39,
#   'loan_status': 1,
#   'loan_percent_income': 0.32,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 23,
#   'person_income': 115000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 2.0,
#   'loan_intent': 'EDUCATION',
#   'loan_grade': 'A',
#   'loan_amnt': 35000,
#   'loan_int_rate': 7.9,
#   'loan_status': 0,
#   'loan_percent_income': 0.3,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 23,
#   'person_income': 500000,
#   'person_home_ownership': 'MORTGAGE',
#   'person_emp_length': 7.0,
#   'loan_intent': 'DEBTCONSOLIDATION',
#   'loan_grade': 'B',
#   'loan_amnt': 30000,
#   'loan_int_rate': 10.65,
#   'loan_status': 0,
#   'loan_percent_income': 0.06,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 23,
#   'person_income': 120000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 0.0,
#   'loan_intent': 'EDUCATION',
#   'loan_grade': 'A',
#   'loan_amnt': 35000,
#   'loan_int_rate': 7.9,
#   'loan_status': 0,
#   'loan_percent_income': 0.29,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 23,
#   'person_income': 92111,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 7.0,
#   'loan_intent': 'MEDICAL',
#   'loan_grade': 'F',
#   'loan_amnt': 35000,
#   'loan_int_rate': 20.25,
#   'loan_status': 1,
#   'loan_percent_income': 0.32,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 23,
#   'person_income': 113000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 8.0,
#   'loan_intent': 'DEBTCONSOLIDATION',
#   'loan_grade': 'D',
#   'loan_amnt': 35000,
#   'loan_int_rate': 18.25,
#   'loan_status': 1,
#   'loan_percent_income': 0.31,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 24,
#   'person_income': 10800,
#   'person_home_ownership': 'MORTGAGE',
#   'person_emp_length': 8.0,
#   'loan_intent': 'EDUCATION',
#   'loan_grade': 'B',
#   'loan_amnt': 1750,
#   'loan_int_rate': 10.99,
#   'loan_status': 1,
#   'loan_percent_income': 0.16,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 25,
#   'person_income': 162500,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 2.0,
#   'loan_intent': 'VENTURE',
#   'loan_grade': 'A',
#   'loan_amnt': 35000,
#   'loan_int_rate': 7.49,
#   'loan_status': 0,
#   'loan_percent_income': 0.22,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 25,
#   'person_income': 137000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 9.0,
#   'loan_intent': 'PERSONAL',
#   'loan_grade': 'E',
#   'loan_amnt': 34800,
#   'loan_int_rate': 16.77,
#   'loan_status': 0,
#   'loan_percent_income': 0.25,
#   'cb_person_default_on_file': 'Y',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 22,
#   'person_income': 65000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 4.0,
#   'loan_intent': 'EDUCATION',
#   'loan_grade': 'D',
#   'loan_amnt': 34000,
#   'loan_int_rate': 17.58,
#   'loan_status': 1,
#   'loan_percent_income': 0.52,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 24,
#   'person_income': 10980,
#   'person_home_ownership': 'OWN',
#   'person_emp_length': 0.0,
#   'loan_intent': 'PERSONAL',
#   'loan_grade': 'A',
#   'loan_amnt': 1500,
#   'loan_int_rate': 7.29,
#   'loan_status': 0,
#   'loan_percent_income': 0.14,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 22,
#   'person_income': 80000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 3.0,
#   'loan_intent': 'PERSONAL',
#   'loan_grade': 'D',
#   'loan_amnt': 33950,
#   'loan_int_rate': 14.54,
#   'loan_status': 1,
#   'loan_percent_income': 0.42,
#   'cb_person_default_on_file': 'Y',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 24,
#   'person_income': 67746,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 8.0,
#   'loan_intent': 'HOMEIMPROVEMENT',
#   'loan_grade': 'C',
#   'loan_amnt': 33000,
#   'loan_int_rate': 12.68,
#   'loan_status': 1,
#   'loan_percent_income': 0.49,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 21,
#   'person_income': 11000,
#   'person_home_ownership': 'MORTGAGE',
#   'person_emp_length': 3.0,
#   'loan_intent': 'VENTURE',
#   'loan_grade': 'E',
#   'loan_amnt': 4575,
#   'loan_int_rate': 17.74,
#   'loan_status': 1,
#   'loan_percent_income': 0.42,
#   'cb_person_default_on_file': 'Y',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 23,
#   'person_income': 11000,
#   'person_home_ownership': 'OWN',
#   'person_emp_length': 0.0,
#   'loan_intent': 'PERSONAL',
#   'loan_grade': 'A',
#   'loan_amnt': 1400,
#   'loan_int_rate': 9.32,
#   'loan_status': 0,
#   'loan_percent_income': 0.13,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 24,
#   'person_income': 65000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 6.0,
#   'loan_intent': 'HOMEIMPROVEMENT',
#   'loan_grade': 'B',
#   'loan_amnt': 32500,
#   'loan_int_rate': 9.99,
#   'loan_status': 1,
#   'loan_percent_income': 0.5,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 21,
#   'person_income': 11389,
#   'person_home_ownership': 'OTHER',
#   'person_emp_length': 5.0,
#   'loan_intent': 'EDUCATION',
#   'loan_grade': 'C',
#   'loan_amnt': 4000,
#   'loan_int_rate': 12.84,
#   'loan_status': 1,
#   'loan_percent_income': 0.35,
#   'cb_person_default_on_file': 'Y',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 21,
#   'person_income': 11520,
#   'person_home_ownership': 'OWN',
#   'person_emp_length': 5.0,
#   'loan_intent': 'MEDICAL',
#   'loan_grade': 'B',
#   'loan_amnt': 2000,
#   'loan_int_rate': 11.12,
#   'loan_status': 1,
#   'loan_percent_income': 0.17,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 25,
#   'person_income': 120000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 2.0,
#   'loan_intent': 'VENTURE',
#   'loan_grade': 'A',
#   'loan_amnt': 32000,
#   'loan_int_rate': 6.62,
#   'loan_status': 0,
#   'loan_percent_income': 0.27,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 26,
#   'person_income': 95000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 7.0,
#   'loan_intent': 'HOMEIMPROVEMENT',
#   'loan_grade': 'C',
#   'loan_amnt': 31050,
#   'loan_int_rate': 14.17,
#   'loan_status': 1,
#   'loan_percent_income': 0.33,
#   'cb_person_default_on_file': 'Y',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 25,
#   'person_income': 306000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 2.0,
#   'loan_intent': 'DEBTCONSOLIDATION',
#   'loan_grade': 'C',
#   'loan_amnt': 24250,
#   'loan_int_rate': 13.85,
#   'loan_status': 0,
#   'loan_percent_income': 0.08,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 26,
#   'person_income': 300000,
#   'person_home_ownership': 'MORTGAGE',
#   'person_emp_length': 10.0,
#   'loan_intent': 'MEDICAL',
#   'loan_grade': 'C',
#   'loan_amnt': 7800,
#   'loan_int_rate': 13.49,
#   'loan_status': 0,
#   'loan_percent_income': 0.03,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 21,
#   'person_income': 12000,
#   'person_home_ownership': 'OWN',
#   'person_emp_length': 5.0,
#   'loan_intent': 'EDUCATION',
#   'loan_grade': 'A',
#   'loan_amnt': 2500,
#   'loan_int_rate': 7.51,
#   'loan_status': 1,
#   'loan_percent_income': 0.21,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 22,
#   'person_income': 48000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 1.0,
#   'loan_intent': 'EDUCATION',
#   'loan_grade': 'E',
#   'loan_amnt': 30000,
#   'loan_int_rate': 18.39,
#   'loan_status': 1,
#   'loan_percent_income': 0.63,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 24,
#   'person_income': 64000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 8.0,
#   'loan_intent': 'DEBTCONSOLIDATION',
#   'loan_grade': 'D',
#   'loan_amnt': 30000,
#   'loan_int_rate': 14.54,
#   'loan_status': 1,
#   'loan_percent_income': 0.47,
#   'cb_person_default_on_file': 'Y',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 25,
#   'person_income': 75000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 4.0,
#   'loan_intent': 'HOMEIMPROVEMENT',
#   'loan_grade': 'D',
#   'loan_amnt': 30000,
#   'loan_int_rate': 16.89,
#   'loan_status': 1,
#   'loan_percent_income': 0.4,
#   'cb_person_default_on_file': 'Y',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 23,
#   'person_income': 71500,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 3.0,
#   'loan_intent': 'DEBTCONSOLIDATION',
#   'loan_grade': 'D',
#   'loan_amnt': 30000,
#   'loan_int_rate': nan,
#   'loan_status': 1,
#   'loan_percent_income': 0.42,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 26,
#   'person_income': 62050,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 6.0,
#   'loan_intent': 'MEDICAL',
#   'loan_grade': 'E',
#   'loan_amnt': 30000,
#   'loan_int_rate': 17.99,
#   'loan_status': 1,
#   'loan_percent_income': 0.41,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 24,
#   'person_income': 12000,
#   'person_home_ownership': 'OWN',
#   'person_emp_length': 4.0,
#   'loan_intent': 'VENTURE',
#   'loan_grade': 'B',
#   'loan_amnt': 2500,
#   'loan_int_rate': 12.69,
#   'loan_status': 1,
#   'loan_percent_income': 0.21,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 26,
#   'person_income': 300000,
#   'person_home_ownership': 'MORTGAGE',
#   'person_emp_length': 10.0,
#   'loan_intent': 'VENTURE',
#   'loan_grade': 'A',
#   'loan_amnt': 20000,
#   'loan_int_rate': 7.88,
#   'loan_status': 0,
#   'loan_percent_income': 0.07,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 23,
#   'person_income': 300000,
#   'person_home_ownership': 'OWN',
#   'person_emp_length': 1.0,
#   'loan_intent': 'EDUCATION',
#   'loan_grade': 'F',
#   'loan_amnt': 24250,
#   'loan_int_rate': 19.41,
#   'loan_status': 0,
#   'loan_percent_income': 0.08,
#   'cb_person_default_on_file': 'Y',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 26,
#   'person_income': 300000,
#   'person_home_ownership': 'OWN',
#   'person_emp_length': 9.0,
#   'loan_intent': 'HOMEIMPROVEMENT',
#   'loan_grade': 'B',
#   'loan_amnt': 10000,
#   'loan_int_rate': 10.38,
#   'loan_status': 0,
#   'loan_percent_income': 0.03,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 26,
#   'person_income': 300000,
#   'person_home_ownership': 'MORTGAGE',
#   'person_emp_length': 0.0,
#   'loan_intent': 'EDUCATION',
#   'loan_grade': 'D',
#   'loan_amnt': 25000,
#   'loan_int_rate': 15.33,
#   'loan_status': 0,
#   'loan_percent_income': 0.08,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 25,
#   'person_income': 300000,
#   'person_home_ownership': 'MORTGAGE',
#   'person_emp_length': 9.0,
#   'loan_intent': 'HOMEIMPROVEMENT',
#   'loan_grade': 'E',
#   'loan_amnt': 18000,
#   'loan_int_rate': 16.45,
#   'loan_status': 0,
#   'loan_percent_income': 0.06,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 26,
#   'person_income': 80690,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 8.0,
#   'loan_intent': 'PERSONAL',
#   'loan_grade': 'A',
#   'loan_amnt': 30000,
#   'loan_int_rate': 7.49,
#   'loan_status': 1,
#   'loan_percent_income': 0.37,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 22,
#   'person_income': 66300,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 4.0,
#   'loan_intent': 'MEDICAL',
#   'loan_grade': 'B',
#   'loan_amnt': 30000,
#   'loan_int_rate': 12.69,
#   'loan_status': 1,
#   'loan_percent_income': 0.38,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 26,
#   'person_income': 89028,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 0.0,
#   'loan_intent': 'DEBTCONSOLIDATION',
#   'loan_grade': 'A',
#   'loan_amnt': 30000,
#   'loan_int_rate': 6.62,
#   'loan_status': 1,
#   'loan_percent_income': 0.34,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 24,
#   'person_income': 78000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 4.0,
#   'loan_intent': 'DEBTCONSOLIDATION',
#   'loan_grade': 'D',
#   'loan_amnt': 30000,
#   'loan_int_rate': nan,
#   'loan_status': 1,
#   'loan_percent_income': 0.38,
#   'cb_person_default_on_file': 'Y',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 23,
#   'person_income': 78000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 7.0,
#   'loan_intent': 'DEBTCONSOLIDATION',
#   'loan_grade': 'F',
#   'loan_amnt': 30000,
#   'loan_int_rate': 18.62,
#   'loan_status': 1,
#   'loan_percent_income': 0.38,
#   'cb_person_default_on_file': 'Y',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 23,
#   'person_income': 92004,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 6.0,
#   'loan_intent': 'PERSONAL',
#   'loan_grade': 'C',
#   'loan_amnt': 30000,
#   'loan_int_rate': 15.23,
#   'loan_status': 1,
#   'loan_percent_income': 0.33,
#   'cb_person_default_on_file': 'Y',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 23,
#   'person_income': 97000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 7.0,
#   'loan_intent': 'VENTURE',
#   'loan_grade': 'B',
#   'loan_amnt': 30000,
#   'loan_int_rate': 10.65,
#   'loan_status': 1,
#   'loan_percent_income': 0.31,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 25,
#   'person_income': 120000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 9.0,
#   'loan_intent': 'EDUCATION',
#   'loan_grade': 'A',
#   'loan_amnt': 30000,
#   'loan_int_rate': 7.9,
#   'loan_status': 0,
#   'loan_percent_income': 0.25,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 26,
#   'person_income': 280000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 4.0,
#   'loan_intent': 'PERSONAL',
#   'loan_grade': 'C',
#   'loan_amnt': 10000,
#   'loan_int_rate': 15.96,
#   'loan_status': 0,
#   'loan_percent_income': 0.04,
#   'cb_person_default_on_file': 'Y',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 26,
#   'person_income': 277104,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 0.0,
#   'loan_intent': 'VENTURE',
#   'loan_grade': 'B',
#   'loan_amnt': 20000,
#   'loan_int_rate': 11.48,
#   'loan_status': 0,
#   'loan_percent_income': 0.07,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 23,
#   'person_income': 277000,
#   'person_home_ownership': 'OWN',
#   'person_emp_length': 3.0,
#   'loan_intent': 'PERSONAL',
#   'loan_grade': 'A',
#   'loan_amnt': 35000,
#   'loan_int_rate': nan,
#   'loan_status': 0,
#   'loan_percent_income': 0.13,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 25,
#   'person_income': 128000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 9.0,
#   'loan_intent': 'PERSONAL',
#   'loan_grade': 'A',
#   'loan_amnt': 30000,
#   'loan_int_rate': 7.29,
#   'loan_status': 0,
#   'loan_percent_income': 0.23,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 24,
#   'person_income': 12000,
#   'person_home_ownership': 'OWN',
#   'person_emp_length': 2.0,
#   'loan_intent': 'VENTURE',
#   'loan_grade': 'E',
#   'loan_amnt': 1750,
#   'loan_int_rate': nan,
#   'loan_status': 0,
#   'loan_percent_income': 0.15,
#   'cb_person_default_on_file': 'Y',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 21,
#   'person_income': 131000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 0.0,
#   'loan_intent': 'VENTURE',
#   'loan_grade': 'A',
#   'loan_amnt': 30000,
#   'loan_int_rate': 5.99,
#   'loan_status': 0,
#   'loan_percent_income': 0.23,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 22,
#   'person_income': 275000,
#   'person_home_ownership': 'OWN',
#   'person_emp_length': 6.0,
#   'loan_intent': 'VENTURE',
#   'loan_grade': 'B',
#   'loan_amnt': 12000,
#   'loan_int_rate': 11.58,
#   'loan_status': 0,
#   'loan_percent_income': 0.04,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 26,
#   'person_income': 263000,
#   'person_home_ownership': 'MORTGAGE',
#   'person_emp_length': 0.0,
#   'loan_intent': 'EDUCATION',
#   'loan_grade': 'B',
#   'loan_amnt': 10000,
#   'loan_int_rate': nan,
#   'loan_status': 1,
#   'loan_percent_income': 0.04,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 25,
#   'person_income': 221850,
#   'person_home_ownership': 'MORTGAGE',
#   'person_emp_length': 9.0,
#   'loan_intent': 'MEDICAL',
#   'loan_grade': 'D',
#   'loan_amnt': 25000,
#   'loan_int_rate': 15.7,
#   'loan_status': 1,
#   'loan_percent_income': 0.1,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 22,
#   'person_income': 70000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 6.0,
#   'loan_intent': 'EDUCATION',
#   'loan_grade': 'D',
#   'loan_amnt': 29100,
#   'loan_int_rate': 15.99,
#   'loan_status': 1,
#   'loan_percent_income': 0.42,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 22,
#   'person_income': 12000,
#   'person_home_ownership': 'MORTGAGE',
#   'person_emp_length': 7.0,
#   'loan_intent': 'EDUCATION',
#   'loan_grade': 'D',
#   'loan_amnt': 1500,
#   'loan_int_rate': 14.84,
#   'loan_status': 0,
#   'loan_percent_income': 0.13,
#   'cb_person_default_on_file': 'Y',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 26,
#   'person_income': 260000,
#   'person_home_ownership': 'OWN',
#   'person_emp_length': 10.0,
#   'loan_intent': 'HOMEIMPROVEMENT',
#   'loan_grade': 'B',
#   'loan_amnt': 28000,
#   'loan_int_rate': 10.99,
#   'loan_status': 0,
#   'loan_percent_income': 0.11,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 25,
#   'person_income': 259000,
#   'person_home_ownership': 'MORTGAGE',
#   'person_emp_length': 9.0,
#   'loan_intent': 'HOMEIMPROVEMENT',
#   'loan_grade': 'D',
#   'loan_amnt': 20000,
#   'loan_int_rate': 14.42,
#   'loan_status': 0,
#   'loan_percent_income': 0.08,
#   'cb_person_default_on_file': 'Y',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 24,
#   'person_income': 255000,
#   'person_home_ownership': 'MORTGAGE',
#   'person_emp_length': 9.0,
#   'loan_intent': 'EDUCATION',
#   'loan_grade': 'A',
#   'loan_amnt': 9600,
#   'loan_int_rate': 6.99,
#   'loan_status': 0,
#   'loan_percent_income': 0.04,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 25,
#   'person_income': 250000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 2.0,
#   'loan_intent': 'MEDICAL',
#   'loan_grade': 'C',
#   'loan_amnt': 25000,
#   'loan_int_rate': 13.49,
#   'loan_status': 0,
#   'loan_percent_income': 0.1,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 25,
#   'person_income': 12000,
#   'person_home_ownership': 'OWN',
#   'person_emp_length': 0.0,
#   'loan_intent': 'MEDICAL',
#   'loan_grade': 'C',
#   'loan_amnt': 3000,
#   'loan_int_rate': nan,
#   'loan_status': 1,
#   'loan_percent_income': 0.25,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 22,
#   'person_income': 56950,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 6.0,
#   'loan_intent': 'MEDICAL',
#   'loan_grade': 'A',
#   'loan_amnt': 28000,
#   'loan_int_rate': nan,
#   'loan_status': 1,
#   'loan_percent_income': 0.49,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 21,
#   'person_income': 12000,
#   'person_home_ownership': 'OWN',
#   'person_emp_length': 6.0,
#   'loan_intent': 'EDUCATION',
#   'loan_grade': 'C',
#   'loan_amnt': 3000,
#   'loan_int_rate': 13.61,
#   'loan_status': 1,
#   'loan_percent_income': 0.25,
#   'cb_person_default_on_file': 'Y',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 23,
#   'person_income': 65000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 2.0,
#   'loan_intent': 'EDUCATION',
#   'loan_grade': 'A',
#   'loan_amnt': 28000,
#   'loan_int_rate': 7.9,
#   'loan_status': 1,
#   'loan_percent_income': 0.43,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 26,
#   'person_income': 85000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 2.0,
#   'loan_intent': 'VENTURE',
#   'loan_grade': 'A',
#   'loan_amnt': 28000,
#   'loan_int_rate': 7.49,
#   'loan_status': 1,
#   'loan_percent_income': 0.33,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 26,
#   'person_income': 12000,
#   'person_home_ownership': 'OWN',
#   'person_emp_length': 2.0,
#   'loan_intent': 'EDUCATION',
#   'loan_grade': 'A',
#   'loan_amnt': 6100,
#   'loan_int_rate': 7.51,
#   'loan_status': 1,
#   'loan_percent_income': 0.51,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 22,
#   'person_income': 88000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 6.0,
#   'loan_intent': 'VENTURE',
#   'loan_grade': 'B',
#   'loan_amnt': 28000,
#   'loan_int_rate': 9.91,
#   'loan_status': 1,
#   'loan_percent_income': 0.32,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 21,
#   'person_income': 12000,
#   'person_home_ownership': 'OWN',
#   'person_emp_length': 0.0,
#   'loan_intent': 'PERSONAL',
#   'loan_grade': 'C',
#   'loan_amnt': 4200,
#   'loan_int_rate': 13.48,
#   'loan_status': 1,
#   'loan_percent_income': 0.35,
#   'cb_person_default_on_file': 'Y',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 22,
#   'person_income': 12000,
#   'person_home_ownership': 'OWN',
#   'person_emp_length': 6.0,
#   'loan_intent': 'DEBTCONSOLIDATION',
#   'loan_grade': 'A',
#   'loan_amnt': 4750,
#   'loan_int_rate': 7.14,
#   'loan_status': 1,
#   'loan_percent_income': 0.4,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 24,
#   'person_income': 83004,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 0.0,
#   'loan_intent': 'VENTURE',
#   'loan_grade': 'D',
#   'loan_amnt': 28000,
#   'loan_int_rate': 15.99,
#   'loan_status': 1,
#   'loan_percent_income': 0.34,
#   'cb_person_default_on_file': 'Y',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 24,
#   'person_income': 250000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 2.0,
#   'loan_intent': 'EDUCATION',
#   'loan_grade': 'C',
#   'loan_amnt': 18000,
#   'loan_int_rate': 12.98,
#   'loan_status': 0,
#   'loan_percent_income': 0.07,
#   'cb_person_default_on_file': 'Y',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 144,
#   'person_income': 250000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 4.0,
#   'loan_intent': 'VENTURE',
#   'loan_grade': 'C',
#   'loan_amnt': 4800,
#   'loan_int_rate': 13.57,
#   'loan_status': 0,
#   'loan_percent_income': 0.02,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 25,
#   'person_income': 100000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 5.0,
#   'loan_intent': 'DEBTCONSOLIDATION',
#   'loan_grade': 'B',
#   'loan_amnt': 28000,
#   'loan_int_rate': 12.69,
#   'loan_status': 0,
#   'loan_percent_income': 0.28,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 26,
#   'person_income': 110000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 10.0,
#   'loan_intent': 'EDUCATION',
#   'loan_grade': 'A',
#   'loan_amnt': 28000,
#   'loan_int_rate': 8.9,
#   'loan_status': 0,
#   'loan_percent_income': 0.25,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 26,
#   'person_income': 12000,
#   'person_home_ownership': 'OWN',
#   'person_emp_length': 0.0,
#   'loan_intent': 'DEBTCONSOLIDATION',
#   'loan_grade': 'A',
#   'loan_amnt': 2700,
#   'loan_int_rate': nan,
#   'loan_status': 1,
#   'loan_percent_income': 0.23,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 22,
#   'person_income': 108000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 6.0,
#   'loan_intent': 'EDUCATION',
#   'loan_grade': 'B',
#   'loan_amnt': 28000,
#   'loan_int_rate': nan,
#   'loan_status': 1,
#   'loan_percent_income': 0.26,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 23,
#   'person_income': 151200,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 7.0,
#   'loan_intent': 'DEBTCONSOLIDATION',
#   'loan_grade': 'B',
#   'loan_amnt': 28000,
#   'loan_int_rate': 11.11,
#   'loan_status': 0,
#   'loan_percent_income': 0.19,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 24,
#   'person_income': 69000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 2.0,
#   'loan_intent': 'HOMEIMPROVEMENT',
#   'loan_grade': 'A',
#   'loan_amnt': 27600,
#   'loan_int_rate': nan,
#   'loan_status': 1,
#   'loan_percent_income': 0.4,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 21,
#   'person_income': 12000,
#   'person_home_ownership': 'MORTGAGE',
#   'person_emp_length': 5.0,
#   'loan_intent': 'DEBTCONSOLIDATION',
#   'loan_grade': 'E',
#   'loan_amnt': 3250,
#   'loan_int_rate': 15.68,
#   'loan_status': 1,
#   'loan_percent_income': 0.27,
#   'cb_person_default_on_file': 'Y',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 22,
#   'person_income': 70000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 4.0,
#   'loan_intent': 'EDUCATION',
#   'loan_grade': 'C',
#   'loan_amnt': 27500,
#   'loan_int_rate': 13.06,
#   'loan_status': 1,
#   'loan_percent_income': 0.39,
#   'cb_person_default_on_file': 'Y',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 22,
#   'person_income': 240000,
#   'person_home_ownership': 'OWN',
#   'person_emp_length': 6.0,
#   'loan_intent': 'PERSONAL',
#   'loan_grade': 'B',
#   'loan_amnt': 25000,
#   'loan_int_rate': nan,
#   'loan_status': 0,
#   'loan_percent_income': 0.1,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 26,
#   'person_income': 73200,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 5.0,
#   'loan_intent': 'VENTURE',
#   'loan_grade': 'D',
#   'loan_amnt': 27050,
#   'loan_int_rate': 15.62,
#   'loan_status': 1,
#   'loan_percent_income': 0.37,
#   'cb_person_default_on_file': 'Y',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 24,
#   'person_income': 83000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 5.0,
#   'loan_intent': 'PERSONAL',
#   'loan_grade': 'C',
#   'loan_amnt': 27000,
#   'loan_int_rate': 13.49,
#   'loan_status': 1,
#   'loan_percent_income': 0.33,
#   'cb_person_default_on_file': 'Y',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 24,
#   'person_income': 73399,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 0.0,
#   'loan_intent': 'VENTURE',
#   'loan_grade': 'D',
#   'loan_amnt': 27000,
#   'loan_int_rate': nan,
#   'loan_status': 1,
#   'loan_percent_income': 0.37,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 23,
#   'person_income': 62500,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 7.0,
#   'loan_intent': 'MEDICAL',
#   'loan_grade': 'B',
#   'loan_amnt': 26000,
#   'loan_int_rate': 11.71,
#   'loan_status': 1,
#   'loan_percent_income': 0.42,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 23,
#   'person_income': 120000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 1.0,
#   'loan_intent': 'EDUCATION',
#   'loan_grade': 'B',
#   'loan_amnt': 25600,
#   'loan_int_rate': 12.69,
#   'loan_status': 0,
#   'loan_percent_income': 0.21,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 24,
#   'person_income': 12360,
#   'person_home_ownership': 'OWN',
#   'person_emp_length': 2.0,
#   'loan_intent': 'MEDICAL',
#   'loan_grade': 'C',
#   'loan_amnt': 1600,
#   'loan_int_rate': 13.57,
#   'loan_status': 0,
#   'loan_percent_income': 0.13,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 22,
#   'person_income': 60000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 0.0,
#   'loan_intent': 'VENTURE',
#   'loan_grade': 'B',
#   'loan_amnt': 25475,
#   'loan_int_rate': 10.99,
#   'loan_status': 1,
#   'loan_percent_income': 0.42,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 25,
#   'person_income': 234000,
#   'person_home_ownership': 'MORTGAGE',
#   'person_emp_length': 3.0,
#   'loan_intent': 'MEDICAL',
#   'loan_grade': 'C',
#   'loan_amnt': 20000,
#   'loan_int_rate': 14.27,
#   'loan_status': 0,
#   'loan_percent_income': 0.09,
#   'cb_person_default_on_file': 'Y',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 24,
#   'person_income': 234000,
#   'person_home_ownership': 'OWN',
#   'person_emp_length': 8.0,
#   'loan_intent': 'HOMEIMPROVEMENT',
#   'loan_grade': 'B',
#   'loan_amnt': 20000,
#   'loan_int_rate': 8.88,
#   'loan_status': 0,
#   'loan_percent_income': 0.09,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 26,
#   'person_income': 234000,
#   'person_home_ownership': 'MORTGAGE',
#   'person_emp_length': 10.0,
#   'loan_intent': 'HOMEIMPROVEMENT',
#   'loan_grade': 'B',
#   'loan_amnt': 21600,
#   'loan_int_rate': 12.18,
#   'loan_status': 0,
#   'loan_percent_income': 0.09,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 25,
#   'person_income': 221004,
#   'person_home_ownership': 'MORTGAGE',
#   'person_emp_length': 6.0,
#   'loan_intent': 'DEBTCONSOLIDATION',
#   'loan_grade': 'D',
#   'loan_amnt': 11900,
#   'loan_int_rate': 14.42,
#   'loan_status': 1,
#   'loan_percent_income': 0.05,
#   'cb_person_default_on_file': 'Y',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 26,
#   'person_income': 232500,
#   'person_home_ownership': 'MORTGAGE',
#   'person_emp_length': 0.0,
#   'loan_intent': 'MEDICAL',
#   'loan_grade': 'C',
#   'loan_amnt': 25000,
#   'loan_int_rate': 14.17,
#   'loan_status': 0,
#   'loan_percent_income': 0.11,
#   'cb_person_default_on_file': 'Y',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 25,
#   'person_income': 230000,
#   'person_home_ownership': 'MORTGAGE',
#   'person_emp_length': 5.0,
#   'loan_intent': 'MEDICAL',
#   'loan_grade': 'C',
#   'loan_amnt': 35000,
#   'loan_int_rate': 13.99,
#   'loan_status': 0,
#   'loan_percent_income': 0.15,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 23,
#   'person_income': 83000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 7.0,
#   'loan_intent': 'EDUCATION',
#   'loan_grade': 'B',
#   'loan_amnt': 25300,
#   'loan_int_rate': 10.99,
#   'loan_status': 1,
#   'loan_percent_income': 0.3,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 22,
#   'person_income': 12600,
#   'person_home_ownership': 'MORTGAGE',
#   'person_emp_length': nan,
#   'loan_intent': 'PERSONAL',
#   'loan_grade': 'A',
#   'loan_amnt': 2000,
#   'loan_int_rate': 5.42,
#   'loan_status': 1,
#   'loan_percent_income': 0.16,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 25,
#   'person_income': 12600,
#   'person_home_ownership': 'OWN',
#   'person_emp_length': 3.0,
#   'loan_intent': 'PERSONAL',
#   'loan_grade': 'C',
#   'loan_amnt': 1750,
#   'loan_int_rate': 13.61,
#   'loan_status': 0,
#   'loan_percent_income': 0.14,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 21,
#   'person_income': 42500,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 3.0,
#   'loan_intent': 'EDUCATION',
#   'loan_grade': 'C',
#   'loan_amnt': 25000,
#   'loan_int_rate': 12.73,
#   'loan_status': 1,
#   'loan_percent_income': 0.59,
#   'cb_person_default_on_file': 'Y',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 24,
#   'person_income': 41000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 2.0,
#   'loan_intent': 'HOMEIMPROVEMENT',
#   'loan_grade': 'D',
#   'loan_amnt': 25000,
#   'loan_int_rate': nan,
#   'loan_status': 1,
#   'loan_percent_income': 0.61,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 25,
#   'person_income': 12816,
#   'person_home_ownership': 'OWN',
#   'person_emp_length': 0.0,
#   'loan_intent': 'DEBTCONSOLIDATION',
#   'loan_grade': 'C',
#   'loan_amnt': 3000,
#   'loan_int_rate': 12.87,
#   'loan_status': 1,
#   'loan_percent_income': 0.23,
#   'cb_person_default_on_file': 'Y',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 24,
#   'person_income': 12960,
#   'person_home_ownership': 'MORTGAGE',
#   'person_emp_length': 1.0,
#   'loan_intent': 'HOMEIMPROVEMENT',
#   'loan_grade': 'B',
#   'loan_amnt': 3650,
#   'loan_int_rate': 9.91,
#   'loan_status': 1,
#   'loan_percent_income': 0.28,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 26,
#   'person_income': 226000,
#   'person_home_ownership': 'MORTGAGE',
#   'person_emp_length': 4.0,
#   'loan_intent': 'HOMEIMPROVEMENT',
#   'loan_grade': 'B',
#   'loan_amnt': 20000,
#   'loan_int_rate': 11.49,
#   'loan_status': 0,
#   'loan_percent_income': 0.09,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 25,
#   'person_income': 225000,
#   'person_home_ownership': 'MORTGAGE',
#   'person_emp_length': 0.0,
#   'loan_intent': 'HOMEIMPROVEMENT',
#   'loan_grade': 'E',
#   'loan_amnt': 30000,
#   'loan_int_rate': 19.91,
#   'loan_status': 0,
#   'loan_percent_income': 0.13,
#   'cb_person_default_on_file': 'Y',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 26,
#   'person_income': 213000,
#   'person_home_ownership': 'MORTGAGE',
#   'person_emp_length': 6.0,
#   'loan_intent': 'EDUCATION',
#   'loan_grade': 'B',
#   'loan_amnt': 35000,
#   'loan_int_rate': 10.65,
#   'loan_status': 1,
#   'loan_percent_income': 0.16,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 24,
#   'person_income': 225000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 0.0,
#   'loan_intent': 'MEDICAL',
#   'loan_grade': 'B',
#   'loan_amnt': 6000,
#   'loan_int_rate': nan,
#   'loan_status': 0,
#   'loan_percent_income': 0.03,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 24,
#   'person_income': 12960,
#   'person_home_ownership': 'MORTGAGE',
#   'person_emp_length': 0.0,
#   'loan_intent': 'DEBTCONSOLIDATION',
#   'loan_grade': 'B',
#   'loan_amnt': 4500,
#   'loan_int_rate': 11.83,
#   'loan_status': 1,
#   'loan_percent_income': 0.35,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 23,
#   'person_income': 12996,
#   'person_home_ownership': 'OWN',
#   'person_emp_length': 0.0,
#   'loan_intent': 'DEBTCONSOLIDATION',
#   'loan_grade': 'C',
#   'loan_amnt': 2400,
#   'loan_int_rate': 13.49,
#   'loan_status': 1,
#   'loan_percent_income': 0.18,
#   'cb_person_default_on_file': 'Y',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 22,
#   'person_income': 42000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 6.0,
#   'loan_intent': 'MEDICAL',
#   'loan_grade': 'D',
#   'loan_amnt': 25000,
#   'loan_int_rate': 14.59,
#   'loan_status': 1,
#   'loan_percent_income': 0.6,
#   'cb_person_default_on_file': 'Y',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 26,
#   'person_income': 48000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 2.0,
#   'loan_intent': 'EDUCATION',
#   'loan_grade': 'B',
#   'loan_amnt': 25000,
#   'loan_int_rate': 9.64,
#   'loan_status': 1,
#   'loan_percent_income': 0.52,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 25,
#   'person_income': 12996,
#   'person_home_ownership': 'OWN',
#   'person_emp_length': 1.0,
#   'loan_intent': 'MEDICAL',
#   'loan_grade': 'D',
#   'loan_amnt': 3600,
#   'loan_int_rate': 14.59,
#   'loan_status': 1,
#   'loan_percent_income': 0.28,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 22,
#   'person_income': 12996,
#   'person_home_ownership': 'OWN',
#   'person_emp_length': 1.0,
#   'loan_intent': 'EDUCATION',
#   'loan_grade': 'B',
#   'loan_amnt': 4750,
#   'loan_int_rate': nan,
#   'loan_status': 1,
#   'loan_percent_income': 0.37,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 25,
#   'person_income': 42360,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 1.0,
#   'loan_intent': 'EDUCATION',
#   'loan_grade': 'E',
#   'loan_amnt': 25000,
#   'loan_int_rate': 16.35,
#   'loan_status': 1,
#   'loan_percent_income': 0.59,
#   'cb_person_default_on_file': 'Y',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 21,
#   'person_income': 49000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 4.0,
#   'loan_intent': 'EDUCATION',
#   'loan_grade': 'B',
#   'loan_amnt': 25000,
#   'loan_int_rate': 10.99,
#   'loan_status': 1,
#   'loan_percent_income': 0.51,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 25,
#   'person_income': 225000,
#   'person_home_ownership': 'MORTGAGE',
#   'person_emp_length': 0.0,
#   'loan_intent': 'VENTURE',
#   'loan_grade': 'F',
#   'loan_amnt': 25000,
#   'loan_int_rate': 18.67,
#   'loan_status': 0,
#   'loan_percent_income': 0.11,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 26,
#   'person_income': 225000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 1.0,
#   'loan_intent': 'EDUCATION',
#   'loan_grade': 'A',
#   'loan_amnt': 3000,
#   'loan_int_rate': 9.32,
#   'loan_status': 0,
#   'loan_percent_income': 0.01,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 23,
#   'person_income': 225000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 8.0,
#   'loan_intent': 'DEBTCONSOLIDATION',
#   'loan_grade': 'A',
#   'loan_amnt': 7500,
#   'loan_int_rate': 8.63,
#   'loan_status': 0,
#   'loan_percent_income': 0.03,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 26,
#   'person_income': 225000,
#   'person_home_ownership': 'MORTGAGE',
#   'person_emp_length': 2.0,
#   'loan_intent': 'VENTURE',
#   'loan_grade': 'B',
#   'loan_amnt': 25000,
#   'loan_int_rate': 10.08,
#   'loan_status': 0,
#   'loan_percent_income': 0.11,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 22,
#   'person_income': 49464,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 5.0,
#   'loan_intent': 'PERSONAL',
#   'loan_grade': 'B',
#   'loan_amnt': 25000,
#   'loan_int_rate': 11.83,
#   'loan_status': 1,
#   'loan_percent_income': 0.51,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 23,
#   'person_income': 50000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 1.0,
#   'loan_intent': 'DEBTCONSOLIDATION',
#   'loan_grade': 'A',
#   'loan_amnt': 25000,
#   'loan_int_rate': 7.9,
#   'loan_status': 1,
#   'loan_percent_income': 0.5,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 25,
#   'person_income': 50000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 4.0,
#   'loan_intent': 'HOMEIMPROVEMENT',
#   'loan_grade': 'A',
#   'loan_amnt': 25000,
#   'loan_int_rate': 5.99,
#   'loan_status': 1,
#   'loan_percent_income': 0.5,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 24,
#   'person_income': 44000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 2.0,
#   'loan_intent': 'DEBTCONSOLIDATION',
#   'loan_grade': 'D',
#   'loan_amnt': 25000,
#   'loan_int_rate': 15.33,
#   'loan_status': 1,
#   'loan_percent_income': 0.57,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 23,
#   'person_income': 50000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 1.0,
#   'loan_intent': 'VENTURE',
#   'loan_grade': 'B',
#   'loan_amnt': 25000,
#   'loan_int_rate': 11.83,
#   'loan_status': 1,
#   'loan_percent_income': 0.5,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 22,
#   'person_income': 50004,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 0.0,
#   'loan_intent': 'VENTURE',
#   'loan_grade': 'B',
#   'loan_amnt': 25000,
#   'loan_int_rate': 10.36,
#   'loan_status': 1,
#   'loan_percent_income': 0.5,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 22,
#   'person_income': 50004,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 3.0,
#   'loan_intent': 'VENTURE',
#   'loan_grade': 'C',
#   'loan_amnt': 25000,
#   'loan_int_rate': 12.23,
#   'loan_status': 1,
#   'loan_percent_income': 0.5,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 22,
#   'person_income': 52000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 2.0,
#   'loan_intent': 'EDUCATION',
#   'loan_grade': 'B',
#   'loan_amnt': 25000,
#   'loan_int_rate': 11.11,
#   'loan_status': 1,
#   'loan_percent_income': 0.48,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 23,
#   'person_income': 13200,
#   'person_home_ownership': 'OWN',
#   'person_emp_length': 3.0,
#   'loan_intent': 'DEBTCONSOLIDATION',
#   'loan_grade': 'A',
#   'loan_amnt': 4950,
#   'loan_int_rate': 7.9,
#   'loan_status': 1,
#   'loan_percent_income': 0.38,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 24,
#   'person_income': 220000,
#   'person_home_ownership': 'MORTGAGE',
#   'person_emp_length': 1.0,
#   'loan_intent': 'EDUCATION',
#   'loan_grade': 'B',
#   'loan_amnt': 25000,
#   'loan_int_rate': 11.58,
#   'loan_status': 0,
#   'loan_percent_income': 0.11,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 23,
#   'person_income': 216000,
#   'person_home_ownership': 'MORTGAGE',
#   'person_emp_length': 5.0,
#   'loan_intent': 'DEBTCONSOLIDATION',
#   'loan_grade': 'A',
#   'loan_amnt': 21000,
#   'loan_int_rate': 8.9,
#   'loan_status': 0,
#   'loan_percent_income': 0.1,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 25,
#   'person_income': 216000,
#   'person_home_ownership': 'MORTGAGE',
#   'person_emp_length': 2.0,
#   'loan_intent': 'EDUCATION',
#   'loan_grade': 'D',
#   'loan_amnt': 25000,
#   'loan_int_rate': 16.07,
#   'loan_status': 0,
#   'loan_percent_income': 0.12,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 26,
#   'person_income': 216000,
#   'person_home_ownership': 'MORTGAGE',
#   'person_emp_length': 10.0,
#   'loan_intent': 'EDUCATION',
#   'loan_grade': 'C',
#   'loan_amnt': 20000,
#   'loan_int_rate': 14.22,
#   'loan_status': 0,
#   'loan_percent_income': 0.09,
#   'cb_person_default_on_file': 'Y',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 23,
#   'person_income': 215000,
#   'person_home_ownership': 'MORTGAGE',
#   'person_emp_length': 7.0,
#   'loan_intent': 'MEDICAL',
#   'loan_grade': 'C',
#   'loan_amnt': 35000,
#   'loan_int_rate': 14.79,
#   'loan_status': 0,
#   'loan_percent_income': 0.16,
#   'cb_person_default_on_file': 'Y',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 26,
#   'person_income': 215000,
#   'person_home_ownership': 'MORTGAGE',
#   'person_emp_length': 11.0,
#   'loan_intent': 'EDUCATION',
#   'loan_grade': 'A',
#   'loan_amnt': 12000,
#   'loan_int_rate': 7.88,
#   'loan_status': 0,
#   'loan_percent_income': 0.06,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 23,
#   'person_income': 52000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 1.0,
#   'loan_intent': 'PERSONAL',
#   'loan_grade': 'C',
#   'loan_amnt': 25000,
#   'loan_int_rate': 13.22,
#   'loan_status': 1,
#   'loan_percent_income': 0.48,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 26,
#   'person_income': 46000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 2.0,
#   'loan_intent': 'DEBTCONSOLIDATION',
#   'loan_grade': 'D',
#   'loan_amnt': 25000,
#   'loan_int_rate': 11.86,
#   'loan_status': 1,
#   'loan_percent_income': 0.54,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 22,
#   'person_income': 53000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 5.0,
# ...
#   'loan_percent_income': 0.4,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 25,
#   'person_income': 46000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 8.0,
#   'loan_intent': 'DEBTCONSOLIDATION',
#   'loan_grade': 'C',
#   'loan_amnt': 18250,
#   'loan_int_rate': 14.26,
#   'loan_status': 1,
#   'loan_percent_income': 0.4,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 25,
#   'person_income': 55044,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 4.0,
#   'loan_intent': 'VENTURE',
#   'loan_grade': 'E',
#   'loan_amnt': 18250,
#   'loan_int_rate': 17.56,
#   'loan_status': 1,
#   'loan_percent_income': 0.33,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 25,
#   'person_income': 49200,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': nan,
#   'loan_intent': 'VENTURE',
#   'loan_grade': 'D',
#   'loan_amnt': 18250,
#   'loan_int_rate': 14.83,
#   'loan_status': 1,
#   'loan_percent_income': 0.37,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 22,
#   'person_income': 50000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 6.0,
#   'loan_intent': 'DEBTCONSOLIDATION',
#   'loan_grade': 'E',
#   'loan_amnt': 18250,
#   'loan_int_rate': 16.7,
#   'loan_status': 1,
#   'loan_percent_income': 0.36,
#   'cb_person_default_on_file': 'Y',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 23,
#   'person_income': 50000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 4.0,
#   'loan_intent': 'VENTURE',
#   'loan_grade': 'B',
#   'loan_amnt': 18225,
#   'loan_int_rate': 10.74,
#   'loan_status': 1,
#   'loan_percent_income': 0.36,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 26,
#   'person_income': 44000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 0.0,
#   'loan_intent': 'HOMEIMPROVEMENT',
#   'loan_grade': 'D',
#   'loan_amnt': 18225,
#   'loan_int_rate': 14.91,
#   'loan_status': 1,
#   'loan_percent_income': 0.41,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 24,
#   'person_income': 36000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 4.0,
#   'loan_intent': 'VENTURE',
#   'loan_grade': 'B',
#   'loan_amnt': 18200,
#   'loan_int_rate': 8.88,
#   'loan_status': 1,
#   'loan_percent_income': 0.51,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 25,
#   'person_income': 36400,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 2.0,
#   'loan_intent': 'PERSONAL',
#   'loan_grade': 'B',
#   'loan_amnt': 18200,
#   'loan_int_rate': 9.91,
#   'loan_status': 1,
#   'loan_percent_income': 0.5,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 22,
#   'person_income': 36000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 6.0,
#   'loan_intent': 'DEBTCONSOLIDATION',
#   'loan_grade': 'B',
#   'loan_amnt': 18200,
#   'loan_int_rate': 11.71,
#   'loan_status': 1,
#   'loan_percent_income': 0.51,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 24,
#   'person_income': 55000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 4.0,
#   'loan_intent': 'EDUCATION',
#   'loan_grade': 'B',
#   'loan_amnt': 18200,
#   'loan_int_rate': 10.99,
#   'loan_status': 1,
#   'loan_percent_income': 0.33,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 23,
#   'person_income': 27000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 2.0,
#   'loan_intent': 'VENTURE',
#   'loan_grade': 'C',
#   'loan_amnt': 18000,
#   'loan_int_rate': 11.54,
#   'loan_status': 1,
#   'loan_percent_income': 0.67,
#   'cb_person_default_on_file': 'Y',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 23,
#   'person_income': 24000,
#   'person_home_ownership': 'OWN',
#   'person_emp_length': 2.0,
#   'loan_intent': 'EDUCATION',
#   'loan_grade': 'D',
#   'loan_amnt': 8000,
#   'loan_int_rate': 15.62,
#   'loan_status': 0,
#   'loan_percent_income': 0.33,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 23,
#   'person_income': 33000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 4.0,
#   'loan_intent': 'VENTURE',
#   'loan_grade': 'B',
#   'loan_amnt': 18000,
#   'loan_int_rate': 9.91,
#   'loan_status': 1,
#   'loan_percent_income': 0.55,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 21,
#   'person_income': 36000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': nan,
#   'loan_intent': 'PERSONAL',
#   'loan_grade': 'B',
#   'loan_amnt': 18000,
#   'loan_int_rate': 9.88,
#   'loan_status': 1,
#   'loan_percent_income': 0.5,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 21,
#   'person_income': 30720,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 5.0,
#   'loan_intent': 'EDUCATION',
#   'loan_grade': 'C',
#   'loan_amnt': 18000,
#   'loan_int_rate': 13.48,
#   'loan_status': 1,
#   'loan_percent_income': 0.59,
#   'cb_person_default_on_file': 'Y',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 23,
#   'person_income': 39996,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 2.0,
#   'loan_intent': 'EDUCATION',
#   'loan_grade': 'B',
#   'loan_amnt': 18000,
#   'loan_int_rate': 9.25,
#   'loan_status': 1,
#   'loan_percent_income': 0.45,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 25,
#   'person_income': 40000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 2.0,
#   'loan_intent': 'MEDICAL',
#   'loan_grade': 'C',
#   'loan_amnt': 18000,
#   'loan_int_rate': 13.11,
#   'loan_status': 1,
#   'loan_percent_income': 0.45,
#   'cb_person_default_on_file': 'Y',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 22,
#   'person_income': 24000,
#   'person_home_ownership': 'MORTGAGE',
#   'person_emp_length': 2.0,
#   'loan_intent': 'DEBTCONSOLIDATION',
#   'loan_grade': 'B',
#   'loan_amnt': 5000,
#   'loan_int_rate': 10.99,
#   'loan_status': 0,
#   'loan_percent_income': 0.21,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 25,
#   'person_income': 42000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 3.0,
#   'loan_intent': 'VENTURE',
#   'loan_grade': 'A',
#   'loan_amnt': 18000,
#   'loan_int_rate': 6.17,
#   'loan_status': 1,
#   'loan_percent_income': 0.43,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 24,
#   'person_income': 24000,
#   'person_home_ownership': 'MORTGAGE',
#   'person_emp_length': 3.0,
#   'loan_intent': 'MEDICAL',
#   'loan_grade': 'A',
#   'loan_amnt': 8000,
#   'loan_int_rate': 5.99,
#   'loan_status': 0,
#   'loan_percent_income': 0.33,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 24,
#   'person_income': 24000,
#   'person_home_ownership': 'OWN',
#   'person_emp_length': 1.0,
#   'loan_intent': 'EDUCATION',
#   'loan_grade': 'A',
#   'loan_amnt': 2400,
#   'loan_int_rate': 7.49,
#   'loan_status': 0,
#   'loan_percent_income': 0.1,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 24,
#   'person_income': 42765,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 9.0,
#   'loan_intent': 'DEBTCONSOLIDATION',
#   'loan_grade': 'C',
#   'loan_amnt': 18000,
#   'loan_int_rate': 11.03,
#   'loan_status': 1,
#   'loan_percent_income': 0.42,
#   'cb_person_default_on_file': 'Y',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 24,
#   'person_income': 43000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 9.0,
#   'loan_intent': 'MEDICAL',
#   'loan_grade': 'A',
#   'loan_amnt': 18000,
#   'loan_int_rate': 7.9,
#   'loan_status': 1,
#   'loan_percent_income': 0.42,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 22,
#   'person_income': 44000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 7.0,
#   'loan_intent': 'EDUCATION',
#   'loan_grade': 'C',
#   'loan_amnt': 18000,
#   'loan_int_rate': 13.57,
#   'loan_status': 1,
#   'loan_percent_income': 0.41,
#   'cb_person_default_on_file': 'Y',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 24,
#   'person_income': 44000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 6.0,
#   'loan_intent': 'VENTURE',
#   'loan_grade': 'B',
#   'loan_amnt': 18000,
#   'loan_int_rate': 12.18,
#   'loan_status': 1,
#   'loan_percent_income': 0.41,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 25,
#   'person_income': 39000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 3.0,
#   'loan_intent': 'MEDICAL',
#   'loan_grade': 'E',
#   'loan_amnt': 18000,
#   'loan_int_rate': 17.19,
#   'loan_status': 1,
#   'loan_percent_income': 0.46,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 22,
#   'person_income': 46800,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 6.0,
#   'loan_intent': 'MEDICAL',
#   'loan_grade': 'C',
#   'loan_amnt': 18000,
#   'loan_int_rate': 15.23,
#   'loan_status': 1,
#   'loan_percent_income': 0.38,
#   'cb_person_default_on_file': 'Y',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 22,
#   'person_income': 48000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 5.0,
#   'loan_intent': 'EDUCATION',
#   'loan_grade': 'B',
#   'loan_amnt': 18000,
#   'loan_int_rate': nan,
#   'loan_status': 1,
#   'loan_percent_income': 0.38,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 24,
#   'person_income': 42000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 8.0,
#   'loan_intent': 'HOMEIMPROVEMENT',
#   'loan_grade': 'D',
#   'loan_amnt': 18000,
#   'loan_int_rate': 14.46,
#   'loan_status': 1,
#   'loan_percent_income': 0.43,
#   'cb_person_default_on_file': 'Y',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 24,
#   'person_income': 24000,
#   'person_home_ownership': 'OWN',
#   'person_emp_length': 5.0,
#   'loan_intent': 'VENTURE',
#   'loan_grade': 'A',
#   'loan_amnt': 4200,
#   'loan_int_rate': 6.99,
#   'loan_status': 0,
#   'loan_percent_income': 0.17,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 24,
#   'person_income': 43400,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 2.0,
#   'loan_intent': 'DEBTCONSOLIDATION',
#   'loan_grade': 'E',
#   'loan_amnt': 18000,
#   'loan_int_rate': 16.63,
#   'loan_status': 1,
#   'loan_percent_income': 0.41,
#   'cb_person_default_on_file': 'Y',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 24,
#   'person_income': 50000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 1.0,
#   'loan_intent': 'MEDICAL',
#   'loan_grade': 'B',
#   'loan_amnt': 18000,
#   'loan_int_rate': 12.42,
#   'loan_status': 1,
#   'loan_percent_income': 0.36,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 24,
#   'person_income': 50000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 4.0,
#   'loan_intent': 'VENTURE',
#   'loan_grade': 'A',
#   'loan_amnt': 18000,
#   'loan_int_rate': 7.9,
#   'loan_status': 1,
#   'loan_percent_income': 0.36,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 23,
#   'person_income': 24000,
#   'person_home_ownership': 'MORTGAGE',
#   'person_emp_length': 2.0,
#   'loan_intent': 'MEDICAL',
#   'loan_grade': 'D',
#   'loan_amnt': 5000,
#   'loan_int_rate': 15.99,
#   'loan_status': 1,
#   'loan_percent_income': 0.21,
#   'cb_person_default_on_file': 'Y',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 23,
#   'person_income': 24000,
#   'person_home_ownership': 'OWN',
#   'person_emp_length': nan,
#   'loan_intent': 'PERSONAL',
#   'loan_grade': 'B',
#   'loan_amnt': 4200,
#   'loan_int_rate': 10.99,
#   'loan_status': 0,
#   'loan_percent_income': 0.17,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 26,
#   'person_income': 50000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 5.0,
#   'loan_intent': 'EDUCATION',
#   'loan_grade': 'C',
#   'loan_amnt': 18000,
#   'loan_int_rate': 13.11,
#   'loan_status': 1,
#   'loan_percent_income': 0.36,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 22,
#   'person_income': 50000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 6.0,
#   'loan_intent': 'VENTURE',
#   'loan_grade': 'C',
#   'loan_amnt': 18000,
#   'loan_int_rate': 13.79,
#   'loan_status': 1,
#   'loan_percent_income': 0.36,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 22,
#   'person_income': 24000,
#   'person_home_ownership': 'OWN',
#   'person_emp_length': 3.0,
#   'loan_intent': 'EDUCATION',
#   'loan_grade': 'B',
#   'loan_amnt': 2500,
#   'loan_int_rate': 10.59,
#   'loan_status': 0,
#   'loan_percent_income': 0.1,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 22,
#   'person_income': 52000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 6.0,
#   'loan_intent': 'EDUCATION',
#   'loan_grade': 'C',
#   'loan_amnt': 18000,
#   'loan_int_rate': nan,
#   'loan_status': 1,
#   'loan_percent_income': 0.35,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 22,
#   'person_income': 24000,
#   'person_home_ownership': 'OWN',
#   'person_emp_length': 1.0,
#   'loan_intent': 'MEDICAL',
#   'loan_grade': 'C',
#   'loan_amnt': 6000,
#   'loan_int_rate': 12.68,
#   'loan_status': 0,
#   'loan_percent_income': 0.25,
#   'cb_person_default_on_file': 'Y',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 25,
#   'person_income': 52000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 2.0,
#   'loan_intent': 'VENTURE',
#   'loan_grade': 'C',
#   'loan_amnt': 18000,
#   'loan_int_rate': 12.98,
#   'loan_status': 1,
#   'loan_percent_income': 0.35,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 22,
#   'person_income': 52000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 1.0,
#   'loan_intent': 'VENTURE',
#   'loan_grade': 'C',
#   'loan_amnt': 18000,
#   'loan_int_rate': 13.85,
#   'loan_status': 1,
#   'loan_percent_income': 0.35,
#   'cb_person_default_on_file': 'Y',
#   'cb_person_cred_hist_length': 4},
#  {'person_age': 25,
#   'person_income': 52526,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 9.0,
#   'loan_intent': 'VENTURE',
#   'loan_grade': 'B',
#   'loan_amnt': 18000,
#   'loan_int_rate': 12.21,
#   'loan_status': 1,
#   'loan_percent_income': 0.34,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 22,
#   'person_income': 46610,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 6.0,
#   'loan_intent': 'DEBTCONSOLIDATION',
#   'loan_grade': 'B',
#   'loan_amnt': 18000,
#   'loan_int_rate': 10.71,
#   'loan_status': 1,
#   'loan_percent_income': 0.39,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 24,
#   'person_income': 48000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 5.0,
#   'loan_intent': 'PERSONAL',
#   'loan_grade': 'A',
#   'loan_amnt': 18000,
#   'loan_int_rate': 6.54,
#   'loan_status': 1,
#   'loan_percent_income': 0.38,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 23,
#   'person_income': 24000,
#   'person_home_ownership': 'OWN',
#   'person_emp_length': 0.0,
#   'loan_intent': 'PERSONAL',
#   'loan_grade': 'A',
#   'loan_amnt': 8000,
#   'loan_int_rate': 5.79,
#   'loan_status': 0,
#   'loan_percent_income': 0.33,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 3},
#  {'person_age': 25,
#   'person_income': 55000,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 2.0,
#   'loan_intent': 'EDUCATION',
#   'loan_grade': 'C',
#   'loan_amnt': 18000,
#   'loan_int_rate': 12.84,
#   'loan_status': 1,
#   'loan_percent_income': 0.33,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 2},
#  {'person_age': 25,
#   'person_income': 55344,
#   'person_home_ownership': 'RENT',
#   'person_emp_length': 2.0,
#   'loan_intent': 'HOMEIMPROVEMENT',
#   'loan_grade': 'B',
#   'loan_amnt': 18000,
#   'loan_int_rate': 10.99,
#   'loan_status': 1,
#   'loan_percent_income': 0.33,
#   'cb_person_default_on_file': 'N',
#   'cb_person_cred_hist_length': 4},
#  ...]

# %%
len(data)
# Out:
# 32581

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

# %%
df=pd.DataFrame(list(collection.find()))
df.head()
# Out:
#                         _id  person_age  person_income person_home_ownership  \
# 0  67d80e4bcd6f2f2b9b72e12b          22          59000                  RENT
# 1  67d80e4bcd6f2f2b9b72e12c          21           9600                   OWN
# 2  67d80e4bcd6f2f2b9b72e12d          25           9600              MORTGAGE
# 3  67d80e4bcd6f2f2b9b72e12e          23          65500                  RENT
# 4  67d80e4bcd6f2f2b9b72e12f          24          54400                  RENT
#
#    person_emp_length loan_intent loan_grade  loan_amnt  loan_int_rate  \
# 0              123.0    PERSONAL          D      35000          16.02
# 1                5.0   EDUCATION          B       1000          11.14
# 2                1.0     MEDICAL          C       5500          12.87
# 3                4.0     MEDICAL          C      35000          15.23
# 4                8.0     MEDICAL          C      35000          14.27
#
#    loan_status  loan_percent_income cb_person_default_on_file  \
# 0            1                 0.59                         Y
# 1            0                 0.10                         N
# 2            1                 0.57                         N
# 3            1                 0.53                         N
# 4            1                 0.55                         Y
#
#    cb_person_cred_hist_length
# 0                           3
# 1                           2
# 2                           3
# 3                           2
# 4                           4
